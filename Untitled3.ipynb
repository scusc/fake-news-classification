# %%
import numpy as np # linear algebra
import pandas as pd

# %%
from tensorflow.python.client import device_lib

def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print(get_available_devices())
# Out:
# ['/device:CPU:0', '/device:XLA_CPU:0', '/device:GPU:0', '/device:XLA_GPU:0']

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import nltk
import re
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
#Now keras libraries
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, LSTM, Conv1D, MaxPool1D, Bidirectional
from tensorflow.keras.models import Model

# %%
df1 = pd.read_csv("train.csv")
df1
# Out:
#        index                                              title  \
# 0          0  PRESIDENT TRUMP Explains New “America First” R...
# 1          1  TERMINALLY ILL FORMER MISS WI: “Until my last ...
# 2          2   Cruz Humiliated By Moderator After Lie About ...
# 3          3  Russia revels in Trump victory, looks to sanct...
# 4          4  Trump's bid to open U.S. monuments to developm...
# ...      ...                                                ...
# 39995  39995  U.S. officials step up rhetoric on Russia link...
# 39996  39996   McDonald’s Manager To Hispanic Customer: ‘Can...
# 39997  39997  SMUG LIBERAL LAW PROFESSOR SHUT DOWN BY TUCKER...
# 39998  39998          Robert Parry: Sorting Out the Russia Mess
# 39999  39999  Israeli missiles hit military post near Damasc...
#
#                                                     text       subject  \
# 0      That s what we re talking about! Another campa...      politics
# 1      How is it that Sean Hannity is the only media ...      politics
# 2      Almost immediately after learning that longtim...          News
# 3      MOSCOW (Reuters) - For all their mutual praise...  politicsNews
# 4      WASHINGTON (Reuters) - The Trump administratio...  politicsNews
# ...                                                  ...           ...
# 39995  (Reuters) - Republican vice presidential candi...  politicsNews
# 39996  An employee working at a North Carolina McDona...          News
# 39997  Tucker to sanctuary city supporter: how did a ...      politics
# 39998  Consortium News Exclusive: The U.S. mainstream...       US_News
# 39999  BEIRUT (Reuters) - Israeli missiles struck a m...     worldnews
#
#                      date class Unnamed: 6
# 0             Aug 2, 2017  Fake        NaN
# 1             Oct 4, 2016  Fake        NaN
# 2       February 13, 2016  Fake        NaN
# 3       November 9, 2016   Real        NaN
# 4           May 26, 2017   Real        NaN
# ...                   ...   ...        ...
# 39995   October 16, 2016   Real        NaN
# 39996  September 13, 2017  Fake        NaN
# 39997        Mar 29, 2017  Fake        NaN
# 39998    October 31, 2017  Fake        NaN
# 39999   December 2, 2017   Real        NaN
#
# [40000 rows x 7 columns]

# %%
df1.drop(columns=['index','date','Unnamed: 6'],inplace=True)
df = pd.get_dummies(df1,drop_first=True,columns=['class'])
df.drop(columns=['class_February 5, 2017'],inplace=True)
df.rename(columns={'class_Real':'validity'},inplace=True)
df
# Out:
#                                                    title  \
# 0      PRESIDENT TRUMP Explains New “America First” R...
# 1      TERMINALLY ILL FORMER MISS WI: “Until my last ...
# 2       Cruz Humiliated By Moderator After Lie About ...
# 3      Russia revels in Trump victory, looks to sanct...
# 4      Trump's bid to open U.S. monuments to developm...
# ...                                                  ...
# 39995  U.S. officials step up rhetoric on Russia link...
# 39996   McDonald’s Manager To Hispanic Customer: ‘Can...
# ['president', 'trump', 'explains', 'america', 'raise', 'welfare', 'immigrants', 'migrants', 'favors', 'english', 'speaking', 'immigrants', 'protects', 'jobs', 'minorities', 'workers', 'replaced', 'video', 'talking', 'campaign', 'promise', 'kept', 'wonder', 'democrats', 'media', 'allies', 'fear', 'president', 'trump', 'time', 'politician', 'actually', 'followed', 'promise', 'american', 'voters', 'helped', 'elected', 'president', 'trump', 'joined', 'republican', 'senators', 'wednesday', 'champion', 'legislation', 'overhauling', 'legal', 'immigration', 'america', 'calling', 'merit', 'based', 'significantly', 'admissions', 'decade', 'speaking', 'white', 'house', 'president', 'called', 'significant', 'reform', 'immigration', 'half', 'century', 'candidate', 'campaigned', 'creating', 'merit', 'based', 'immigration', 'protects', 'workers', 'taxpayers', 'today', 'trump', 'said', 'joined', 'georgia', 'david', 'perdue', 'arkansas', 'cotton', 'republicans', 'introduced', 'reforming', 'american', 'immigration', 'strong', 'economy', 'raise', 'february', 'said', 'legislation', 'aims', 'reduce', 'number', 'green', 'cards', 'issued', 'half', 'million', 'year', 'trump', 'perdue', 'cotton', 'argued', 'tuesday', 'skilled', 'unskilled', 'immigration', 'united', 'states', 'depressed', 'wages', 'according', 'fact', 'sheet', 'released', 'reporters', 'favor', 'immigrants', 'educated', 'speak', 'english', 'high', 'paying', 'offers', 'reduce', 'skilled', 'unskilled', 'labor', 'immigration', 'trump', 'said', 'immigrants', 'able', 'financially', 'support', 'families', 'raise', 'prevents', 'migrants', 'immigrants', 'collecting', 'welfare', 'protects', 'workers', 'displaced', 'president', 'said', 'thing', 'going', 'come', 'immediately', 'collect', 'welfare', 'prioritize', 'immediate', 'family', 'members', 'united', 'states', 'residents', 'including', 'spouses', 'young', 'children', 'prioritization', 'extended', 'family', 'members', 'adult', 'children', 'residents', 'legislation', 'eliminates', 'diversity', 'visa', 'lottery', 'limits', 'permanent', 'resident', 'status', 'refugees', 'year', 'trump', 'lamented', 'country', 'record', 'numbers', 'green', 'cards', 'wage', 'immigrants', 'white', 'house', 'said', 'million', 'immigrants', 'accepted', 'united', 'states', 'legal', 'permanent', 'residency', 'year', 'unskilled', 'workers', 'hardest', 'president', 'said', 'minority', 'workers', 'said', 'competing', 'jobs', 'brand', 'arrivals', 'fair', 'people', 'citizens', 'workers', 'said', 'administration', 'said', 'percent', 'immigrant', 'households', 'receive', 'welfare', 'benefits', 'opposed', 'percent', 'native', 'households', 'country', 'entire', 'story', 'news']

# %%
list_words = []
for i in df.clean:
    for j in i:
        list_words.append(j)
print ('Total number of words are: {}'.format(len(list_words)))
# Out:
# Total number of words are: 8253196

# %%
#total unique words
total_unique_words = len(list(set(list_words)))
total_unique_words
# Out:
# 103877

# %%
# Now lets convert words in "clean" column to a string
df['clean_joined'] = df['clean'].apply(lambda x: " ".join(x))
df
# Out:
#                                                    title  \
# 0      PRESIDENT TRUMP Explains New “America First” R...
# 1      TERMINALLY ILL FORMER MISS WI: “Until my last ...
# 2       Cruz Humiliated By Moderator After Lie About ...
# 3      Russia revels in Trump victory, looks to sanct...
# 4      Trump's bid to open U.S. monuments to developm...
# ...                                                  ...
# 39995  U.S. officials step up rhetoric on Russia link...
# 39996   McDonald’s Manager To Hispanic Customer: ‘Can...
# 39997  SMUG LIBERAL LAW PROFESSOR SHUT DOWN BY TUCKER...
# 39998          Robert Parry: Sorting Out the Russia Mess
# 39999  Israeli missiles hit military post near Damasc...
#
#                                                     text       subject  \
# 0      That s what we re talking about! Another campa...      politics
# 1      How is it that Sean Hannity is the only media ...      politics
# 2      Almost immediately after learning that longtim...          News
# 3      MOSCOW (Reuters) - For all their mutual praise...  politicsNews
# 4      WASHINGTON (Reuters) - The Trump administratio...  politicsNews
# ...                                                  ...           ...
# 39995  (Reuters) - Republican vice presidential candi...  politicsNews
# 39996  An employee working at a North Carolina McDona...          News
# 39997  Tucker to sanctuary city supporter: how did a ...      politics
# 39998  Consortium News Exclusive: The U.S. mainstream...       US_News
# 39999  BEIRUT (Reuters) - Israeli missiles struck a m...     worldnews
#
#        validity                                           original  \
# 0             0  PRESIDENT TRUMP Explains New “America First” R...
# 1             0  TERMINALLY ILL FORMER MISS WI: “Until my last ...
# 2             0   Cruz Humiliated By Moderator After Lie About ...
# 3             1  Russia revels in Trump victory, looks to sanct...
# 4             1  Trump's bid to open U.S. monuments to developm...
# ...         ...                                                ...
# 39995         1  U.S. officials step up rhetoric on Russia link...
# 39996         0   McDonald’s Manager To Hispanic Customer: ‘Can...
# 39997         0  SMUG LIBERAL LAW PROFESSOR SHUT DOWN BY TUCKER...
# 39998         0  Robert Parry: Sorting Out the Russia Mess Cons...
# 39999         1  Israeli missiles hit military post near Damasc...
#
#                                                    clean  \
# 0      [president, trump, explains, america, raise, w...
# 1      [terminally, miss, breath, voice, tell, trump,...
# 2      [cruz, humiliated, moderator, presidents, appo...
# 3      [russia, revels, trump, victory, looks, sancti...
# 4      [trump, open, monuments, development, draws, c...
# ...                                                  ...
# 39995  [officials, step, rhetoric, russia, link, emai...
# 39996  [mcdonald, manager, hispanic, customer, spell,...
# 39997  [smug, liberal, professor, shut, tucker, carls...
# 39998  [robert, parry, sorting, russia, mess, consort...
# 39999  [israeli, missiles, military, post, near, dama...
#
#                                             clean_joined
# 0      president trump explains america raise welfare...
# 1      terminally miss breath voice tell trump video ...
# 2      cruz humiliated moderator presidents appointin...
# 3      russia revels trump victory looks sanctions re...
# 4      trump open monuments development draws calls p...
# ...                                                  ...
# 39995  officials step rhetoric russia link email hack...
# 39996  mcdonald manager hispanic customer spell depor...
# 39997  smug liberal professor shut tucker carlson pro...
# 39998  robert parry sorting russia mess consortium ne...
# 39999  israeli missiles military post near damascus s...
#
# [40000 rows x 7 columns]

# %%
df['clean_joined'][1]
# Out:
# 'terminally miss breath voice tell trump video sean hannity media personality able amazing strong women stories american voter hear trump treats women genuine concern miss mellissa young story heartbreaking admiration respect donald trump unmistakeable watch trump international senada adzem miss carrie prajean boller speak hannity'

# %%
# Now maximum length is required to create word embeddings
maxlen = -1
for news in df.clean_joined:
    tokens = nltk.word_tokenize(news) #converts text to tokens (words)
    if (maxlen < len(tokens)):
        maxlen = len(tokens)
print ("The maximum number of words in any news is =", maxlen)
# Out:
# The maximum number of words in any news is = 4405

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.clean_joined, df.validity, test_size = 0.2, random_state = 42)

# %%
from nltk import word_tokenize
# Lets create tokenizer to tokenize the words and conert them into a sequence
tokenizer = Tokenizer(num_words= total_unique_words)
tokenizer.fit_on_texts(x_train) #It creates vocabulary index ("word_index") based on word frequency
train_sequences = tokenizer.texts_to_sequences(x_train) # Replace each word in text with corresponding integer value from "word_index"
test_sequences = tokenizer.texts_to_sequences(x_test)

# %%
len(train_sequences)
# Out:
# 32000

# %%
len(test_sequences)
# Out:
# 8000

# %%
pad_train = pad_sequences(train_sequences, maxlen = 4405, padding = 'post', truncating= 'post')
pad_test = pad_sequences(test_sequences, maxlen=4405, padding = 'post', truncating= 'post')

# %%
for i, news in enumerate(pad_train[:2]):
    print("The padded encoding for news", i+1, " is : ", news)
# Out:
# The padded encoding for news 1  is :  [3277 1215 1311 ...    0    0    0]
# The padded encoding for news 2  is :  [ 753 3848  288 ...    0    0    0]

# %%
for i, news in enumerate(pad_test[:2]):
    print("The padded encoding for news", i+1, " is : ", news)
# Out:
# The padded encoding for news 1  is :  [5944 1649  105 ...    0    0    0]
# The padded encoding for news 2  is :  [35894  1703   675 ...     0     0     0]

# %%
model = Sequential() 

model.add(Embedding(total_unique_words, output_dim = 128)) #Embedding Layer

model.add(Bidirectional(LSTM(128))) #Bi-directional LSTM

#Dense layer
model.add(Dense(128, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid')) # binary classification (0\1)
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics= ['acc'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-28-e8104f3073ef> in <module>
#       1 model = Sequential()
#       2
# ----> 3 model.add(Embedding(total_unique_words, output_dim = 128)) #Embedding Layer
#       4
#       5 model.add(Bidirectional(LSTM(128))) #Bi-directional LSTM
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1096         # Build layer if applicable (if the `build` method has been
#    1097         # overridden).
# -> 1098         self._maybe_build(inputs)
#    1099         cast_inputs = self._maybe_cast_inputs(inputs, input_list)
#    1100
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    2641         # operations.
#    2642         with tf_utils.maybe_init_scope(self):
# -> 2643           self.build(input_shapes)  # pylint:disable=not-callable
#    2644       # We must set also ensure that the layer is marked as built, and the build
#    2645       # shape is stored since user defined build functions may not be calling
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py in wrapper(instance, input_shape)
#     321     if input_shape is not None:
#     322       input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 323     output_shape = fn(instance, input_shape)
#     324     # Return shapes from `fn` as TensorShapes.
#     325     if output_shape is not None:
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\layers\embeddings.py in build(self, input_shape)
#     140             name='embeddings',
#     141             regularizer=self.embeddings_regularizer,
# --> 142             constraint=self.embeddings_constraint)
#     143     else:
#     144       self.embeddings = self.add_weight(
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     612         synchronization=synchronization,
#     613         aggregation=aggregation,
# --> 614         caching_device=caching_device)
#     615     if regularizer is not None:
#     616       # TODO(fchollet): in the future, this should be handled at the
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\training\tracking\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     748         dtype=dtype,
#     749         initializer=initializer,
# --> 750         **kwargs_for_getter)
#     751
#     752     # If we set an initializer and the variable processed it, tracking will not
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\engine\base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     143       synchronization=synchronization,
#     144       aggregation=aggregation,
# --> 145       shape=variable_shape if variable_shape else None)
#     146
#     147
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     258   def __call__(cls, *args, **kwargs):
#     259     if cls is VariableV1:
# --> 260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
#     262       return cls._variable_v2_call(*args, **kwargs)
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     219         synchronization=synchronization,
#     220         aggregation=aggregation,
# --> 221         shape=shape)
#     222
#     223   def _variable_v2_call(cls,
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kwargs)
#     197                         shape=None):
#     198     """Call on Variable class. Useful to force the signature."""
# --> 199     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     200     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     201       previous_getter = _make_getter(getter, previous_getter)
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2595         synchronization=synchronization,
#    2596         aggregation=aggregation,
# -> 2597         shape=shape)
#    2598   else:
#    2599     return variables.RefVariable(
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1516           aggregation=aggregation,
#    1517           shape=shape,
# -> 1518           distribute_strategy=distribute_strategy)
#    1519
#    1520   def _init_from_args(self,
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1649           with ops.name_scope("Initializer"), device_context_manager(None):
#    1650             initial_value = ops.convert_to_tensor(
# -> 1651                 initial_value() if init_from_fn else initial_value,
#    1652                 name="initial_value", dtype=dtype)
#    1653           if shape is not None:
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\keras\initializers\initializers_v2.py in __call__(self, shape, dtype)
#     253        (via `tf.keras.backend.set_floatx(float_dtype)`).
#     254     """
# --> 255     return super(RandomUniform, self).__call__(shape, dtype=_get_dtype(dtype))
#     256
#     257
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\init_ops_v2.py in __call__(self, shape, dtype)
#     321       raise ValueError("Expected float or integer dtype, got %s." % dtype)
#     322     return self._random_generator.random_uniform(shape, self.minval,
# --> 323                                                  self.maxval, dtype)
#     324
#     325   def get_config(self):
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\init_ops_v2.py in random_uniform(self, shape, minval, maxval, dtype)
#    1042       op = random_ops.random_uniform
#    1043     return op(
# -> 1044         shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#    1045
#    1046   def truncated_normal(self, shape, mean, stddev, dtype):
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     300     else:
#     301       result = gen_random_ops.random_uniform(
# --> 302           shape, dtype, seed=seed1, seed2=seed2)
#     303       if minval_is_zero:
#     304         if not maxval_is_one:
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\ops\gen_random_ops.py in random_uniform(shape, dtype, seed, seed2, name)
#     724       return _result
#     725     except _core._NotOkStatusException as e:
# --> 726       _ops.raise_from_not_ok_status(e, name)
#     727     except _core._FallbackException:
#     728       pass
#
# F:\anaconda\envs\gputest\lib\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# F:\anaconda\envs\gputest\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[103877,128] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator cpu [Op:RandomUniform]

# %%
y_train = np.asarray(y_train)

# %%
model.fit(pad_train, y_train, batch_size= 64, validation_split = 0.1, epochs= 3)
